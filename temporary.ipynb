# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plot Normal Distribution

# %%
# Generate random sample with n=100000 data with mean = 0 and sd=1
mu = 0
sd = 1
n = 10000000

# %% [markdown]
# ## Univariate Gaussian Distribution

# %%
random_data = np.random.normal(mu, sd, n)
# Round data to the first dec.
random_data = np.round(random_data, 1)

# %%
df = pd.DataFrame(data=random_data, columns=['Data'])
df.head()
# Out:
#    Data
# 0   1.7
# 1  -1.0
# 2   1.9
# 3   0.0
# 4  -0.8

# %%
df['Data'].value_counts().sort_index().plot(kind='line', figsize=(9,4))
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# ## Bivariate Gaussian Distribution

# %%
n = 1000
random_data = np.random.normal(mu, sd, [n,2])

# %%
df = pd.DataFrame(data=random_data, columns=['X','Y'])
df.head()
# Out:
#           X         Y
# 0 -2.078353 -0.302340
# 1 -1.259002  0.574811
# 2  2.087284  1.504419
# 3 -0.689011 -0.975108
# 4 -0.858363 -0.816103

# %%
df.plot(kind='scatter',x='X', y='Y', figsize=(5,5))
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
sigmoid = lambda x: 1/(1+np.exp(-x))
sigmoid_diff = lambda x: sigmoid(x)*(1 - sigmoid(x))

# %%
line = np.linspace(-10,10)

plt.subplot(121)
plt.plot(line, sigmoid(line))
plt.title('Sigmoid function')

plt.subplot(122)
plt.plot(line, sigmoid_diff(line))
plt.title('Sigmoid derivative')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="953">
